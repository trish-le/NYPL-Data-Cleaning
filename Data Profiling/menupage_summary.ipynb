# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_feather("../Data Files/FEATHER/MenuPage.feather")
df.set_index('id', inplace=True)

# %%
df.shape
# Out:
# (66937, 6)

# %%
df.dtypes
# Out:
# menu_id          int64
# page_number    float64
# image_id        object
# full_height    float64
# full_width     float64
# uuid            object
# dtype: object

# %%
df.head(5)
# Out:
#      menu_id  page_number image_id  full_height  full_width  \
# id
# 119    12460          1.0  1603595       7230.0      5428.0
# 120    12460          2.0  1603596       5428.0      7230.0
# 121    12460          3.0  1603597       7230.0      5428.0
# 122    12460          4.0  1603598       7230.0      5428.0
# 123    12461          1.0  1603591       7230.0      5428.0
#
#                                      uuid
# id
# 119  510d47e4-2955-a3d9-e040-e00a18064a99
# 120  510d47e4-2956-a3d9-e040-e00a18064a99
# 121  510d47e4-2957-a3d9-e040-e00a18064a99
# 122  510d47e4-2958-a3d9-e040-e00a18064a99
# 123  510d47e4-2959-a3d9-e040-e00a18064a99

# %%
df.describe(include="all")
# Out:
#              menu_id   page_number    image_id   full_height    full_width  \
# count   66937.000000  65735.000000       66937  66608.000000  66608.000000
# unique           NaN           NaN       63244           NaN           NaN
# top              NaN           NaN  4000011684           NaN           NaN
# freq             NaN           NaN           5           NaN           NaN
# mean    25653.580904      3.759169         NaN   3859.102856   2778.588398
# std      6158.827683      4.909050         NaN   1156.010307    970.287300
# min     12460.000000      1.000000         NaN    616.000000    558.000000
# 25%     21743.000000      1.000000         NaN   2988.000000   2120.000000
# 50%     26202.000000      2.000000         NaN   3630.000000   2527.000000
# 75%     30531.000000      4.000000         NaN   4617.250000   3295.250000
# max     35526.000000     74.000000         NaN  12044.000000   9175.000000
#
#                                         uuid
# count                                  66937
# unique                                 63041
# top     d8ba80a0-ef9e-012f-faee-58d385a7b928
# freq                                      24
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_percentage.name = 'Percentage of Missing Values'
missing_percentage
# Out:
# menu_id        0.000000
# page_number    1.795718
# image_id       0.000000
# full_height    0.491507
# full_width     0.491507
# uuid           0.000000
# Name: Percentage of Missing Values, dtype: float64

# %%
non_missing_percentage = 100 - missing_percentage
missing_data_percentage = pd.DataFrame({'Missing': missing_percentage, 'Non-Missing': non_missing_percentage})
missing_data_percentage.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Missing vs. Non-Missing Values (Percentage)')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.show()
