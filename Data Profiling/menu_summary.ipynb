# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_feather("../Data Files/FEATHER/Menu.feather")
df.set_index('id', inplace=True)

# %%
df.shape
# Out:
# (17545, 19)

# %%
df.dtypes
# Out:
# name                     object
# sponsor                  object
# event                    object
# venue                    object
# place                    object
# physical_description     object
# occasion                 object
# notes                    object
# call_number              object
# keywords                float64
# language                float64
# date                     object
# location                 object
# location_type           float64
# currency                 object
# currency_symbol          object
# status                   object
# page_count                int64
# dish_count                int64
# dtype: object

# %%
df.head(5)
# Out:
#        name                     sponsor                 event       venue  \
# id
# 12463  None               HOTEL EASTMAN             BREAKFAST  COMMERCIAL
# 12464  None            REPUBLICAN HOUSE              [DINNER]  COMMERCIAL
# 12465  None  NORDDEUTSCHER LLOYD BREMEN  FRUHSTUCK/BREAKFAST;  COMMERCIAL
# 12466  None  NORDDEUTSCHER LLOYD BREMEN                LUNCH;  COMMERCIAL
# 12467  None  NORDDEUTSCHER LLOYD BREMEN               DINNER;  COMMERCIAL
#
#                                     place         physical_description  \
# id
# 12463                     HOT SPRINGS, AR              CARD; 4.75X7.5;
# 12464                    MILWAUKEE, [WI];   CARD; ILLUS; COL; 7.0X9.0;
# 12465  DAMPFER KAISER WILHELM DER GROSSE;    CARD; ILLU; COL; 5.5X8.0;
# 12466  DAMPFER KAISER WILHELM DER GROSSE;    CARD; ILLU; COL; 5.5X8.0;
# 12467  DAMPFER KAISER WILHELM DER GROSSE;  FOLDER; ILLU; COL; 5.5X7.5;
#
#       occasion                                              notes call_number  \
# id
# 12463  EASTER;                                               None   1900-2822
# 12464  EASTER;  WEDGEWOOD BLUE CARD; WHITE EMBOSSED GREEK KEY ...   1900-2825
# 12465     None  MENU IN GERMAN AND ENGLISH; ILLUS, STEAMSHIP A...   1900-2827
# 12466     None  MENU IN GERMAN AND ENGLISH; ILLUS, HARBOR SCEN...   1900-2828
# 12467     None  MENU IN GERMAN AND ENGLISH; ILLUS, HARBOR SCEN...   1900-2829
#
#        keywords  language        date                    location  \
# id
# 12463       NaN       NaN  1900-04-15               Hotel Eastman
# 12464       NaN       NaN  1900-04-15            Republican House
# 12465       NaN       NaN  1900-04-16  Norddeutscher Lloyd Bremen
# 12466       NaN       NaN  1900-04-16  Norddeutscher Lloyd Bremen
# 12467       NaN       NaN  1900-04-16  Norddeutscher Lloyd Bremen
#
#        location_type currency currency_symbol        status  page_count  \
# id
# 12463            NaN     None            None      complete           2
# 12464            NaN     None            None  under review           2
# 12465            NaN     None            None      complete           2
# 12466            NaN     None            None      complete           2
# 12467            NaN     None            None      complete           4
#
#        dish_count
# id
# 12463          67
# 12464          34
# 12465          84
# 12466          63
# 12467          33

# %%
df.describe(include="all")
# Out:
#                    name          sponsor   event       venue     place  \
# count              3197            15984    8154        8119      8123
# unique              797             6370    1770         233      3714
# top     Waldorf Astoria  Waldorf Astoria  DINNER  COMMERCIAL  EN ROUTE
# freq                475              691    1827        4704       293
# mean                NaN              NaN     NaN         NaN       NaN
# std                 NaN              NaN     NaN         NaN       NaN
# min                 NaN              NaN     NaN         NaN       NaN
# 25%                 NaN              NaN     NaN         NaN       NaN
# 50%                 NaN              NaN     NaN         NaN       NaN
# 75%                 NaN              NaN     NaN         NaN       NaN
# max                 NaN              NaN     NaN         NaN       NaN
#
#                   physical_description occasion                      notes  \
# count                            14763     3791                      10613
# unique                            6268      423                       6969
# top     BROADSHEET; ILLUS; 6.5 X 7.75;   DAILY;  Dieter Zander Collection.
# freq                               127      828                        210
# mean                               NaN      NaN                        NaN
# std                                NaN      NaN                        NaN
# min                                NaN      NaN                        NaN
# 25%                                NaN      NaN                        NaN
# 50%                                NaN      NaN                        NaN
# 75%                                NaN      NaN                        NaN
# max                                NaN      NaN                        NaN
#
#        call_number  keywords  language        date         location  \
# count        15983       0.0       0.0       16959            17545
# unique       15936       NaN       NaN        6599             6283
# top       1899-806       NaN       NaN  1915-01-01  Waldorf Astoria
# freq             3       NaN       NaN         263              703
# mean           NaN       NaN       NaN         NaN              NaN
# std            NaN       NaN       NaN         NaN              NaN
# min            NaN       NaN       NaN         NaN              NaN
# 25%            NaN       NaN       NaN         NaN              NaN
# 50%            NaN       NaN       NaN         NaN              NaN
# 75%            NaN       NaN       NaN         NaN              NaN
# max            NaN       NaN       NaN         NaN              NaN
#
#         location_type currency currency_symbol    status    page_count  \
# count             0.0     6456            6456     17545  17545.000000
# unique            NaN       42              34         2           NaN
# top               NaN  Dollars               $  complete           NaN
# freq              NaN     5549            5579     17371           NaN
# mean              NaN      NaN             NaN       NaN      3.484412
# std               NaN      NaN             NaN       NaN      3.295643
# min               NaN      NaN             NaN       NaN      1.000000
# 25%               NaN      NaN             NaN       NaN      2.000000
# 50%               NaN      NaN             NaN       NaN      2.000000
# 75%               NaN      NaN             NaN       NaN      4.000000
# max               NaN      NaN             NaN       NaN     74.000000
#
#           dish_count
# count   17545.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       75.617213
# std        98.435862
# min         0.000000
# 25%        20.000000
# 50%        35.000000
# 75%        93.000000
# max      4053.000000

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_percentage.name = 'Percentage of Missing Values'
missing_percentage
# Out:
# name                     81.778284
# sponsor                   8.897122
# event                    53.525221
# venue                    53.724708
# place                    53.701909
# physical_description     15.856369
# occasion                 78.392704
# notes                    39.509832
# call_number               8.902821
# keywords                100.000000
# language                100.000000
# date                      3.339983
# location                  0.000000
# location_type           100.000000
# currency                 63.203192
# currency_symbol          63.203192
# status                    0.000000
# page_count                0.000000
# dish_count                0.000000
# Name: Percentage of Missing Values, dtype: float64

# %%
non_missing_percentage = 100 - missing_percentage
missing_data_percentage = pd.DataFrame({'Missing': missing_percentage, 'Non-Missing': non_missing_percentage})
missing_data_percentage.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Missing vs. Non-Missing Values (Percentage)')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.xticks(rotation=75)
plt.show()
