# %% [markdown]
# # Menu Table

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_feather("../Data Files/Menu.feather")

# %% [markdown]
# ## Description
#
# Each entry is an individual menu with information on where it was used and who created it (i.e., a hotel or a restaurant)
#
# * There are 17545 records across 20 columns

# %%
df.shape
# Out:
# (17545, 20)

# %%
df.dtypes
# Out:
# id                        int64
# name                     object
# sponsor                  object
# event                    object
# venue                    object
# place                    object
# physical_description     object
# occasion                 object
# notes                    object
# call_number              object
# keywords                float64
# language                float64
# date                     object
# location                 object
# location_type           float64
# currency                 object
# currency_symbol          object
# status                   object
# page_count                int64
# dish_count                int64
# dtype: object

# %%
df.head(5)
# Out:
#       id  name                     sponsor                 event       venue  \
# 0  12463  None               HOTEL EASTMAN             BREAKFAST  COMMERCIAL
# 1  12464  None            REPUBLICAN HOUSE              [DINNER]  COMMERCIAL
# 2  12465  None  NORDDEUTSCHER LLOYD BREMEN  FRUHSTUCK/BREAKFAST;  COMMERCIAL
# 3  12466  None  NORDDEUTSCHER LLOYD BREMEN                LUNCH;  COMMERCIAL
# 4  12467  None  NORDDEUTSCHER LLOYD BREMEN               DINNER;  COMMERCIAL
#
#                                 place         physical_description occasion  \
# 0                     HOT SPRINGS, AR              CARD; 4.75X7.5;  EASTER;
# 1                    MILWAUKEE, [WI];   CARD; ILLUS; COL; 7.0X9.0;  EASTER;
# 2  DAMPFER KAISER WILHELM DER GROSSE;    CARD; ILLU; COL; 5.5X8.0;     None
# 3  DAMPFER KAISER WILHELM DER GROSSE;    CARD; ILLU; COL; 5.5X8.0;     None
# 4  DAMPFER KAISER WILHELM DER GROSSE;  FOLDER; ILLU; COL; 5.5X7.5;     None
#
#                                                notes call_number  keywords  \
# 0                                               None   1900-2822       NaN
# 1  WEDGEWOOD BLUE CARD; WHITE EMBOSSED GREEK KEY ...   1900-2825       NaN
# 2  MENU IN GERMAN AND ENGLISH; ILLUS, STEAMSHIP A...   1900-2827       NaN
# 3  MENU IN GERMAN AND ENGLISH; ILLUS, HARBOR SCEN...   1900-2828       NaN
# 4  MENU IN GERMAN AND ENGLISH; ILLUS, HARBOR SCEN...   1900-2829       NaN
#
#    language        date                    location  location_type currency  \
# 0       NaN  1900-04-15               Hotel Eastman            NaN     None
# 1       NaN  1900-04-15            Republican House            NaN     None
# 2       NaN  1900-04-16  Norddeutscher Lloyd Bremen            NaN     None
# 3       NaN  1900-04-16  Norddeutscher Lloyd Bremen            NaN     None
# 4       NaN  1900-04-16  Norddeutscher Lloyd Bremen            NaN     None
#
#   currency_symbol        status  page_count  dish_count
# 0            None      complete           2          67
# 1            None  under review           2          34
# 2            None      complete           2          84
# 3            None      complete           2          63
# 4            None      complete           4          33

# %%
df.describe(include="all")
# Out:
#                   id             name          sponsor   event       venue  \
# count   17545.000000             3197            15984    8154        8119
# unique           NaN              797             6370    1770         233
# top              NaN  Waldorf Astoria  Waldorf Astoria  DINNER  COMMERCIAL
# freq             NaN              475              691    1827        4704
# mean    25325.953377              NaN              NaN     NaN         NaN
# std      6431.552203              NaN              NaN     NaN         NaN
# min     12463.000000              NaN              NaN     NaN         NaN
# 25%     20742.000000              NaN              NaN     NaN         NaN
# 50%     26165.000000              NaN              NaN     NaN         NaN
# 75%     30707.000000              NaN              NaN     NaN         NaN
# max     35526.000000              NaN              NaN     NaN         NaN
#
#            place            physical_description occasion  \
# count       8123                           14763     3791
# unique      3714                            6268      423
# top     EN ROUTE  BROADSHEET; ILLUS; 6.5 X 7.75;   DAILY;
# freq         293                             127      828
# mean         NaN                             NaN      NaN
# std          NaN                             NaN      NaN
# min          NaN                             NaN      NaN
# 25%          NaN                             NaN      NaN
# 50%          NaN                             NaN      NaN
# 75%          NaN                             NaN      NaN
# max          NaN                             NaN      NaN
#
#                             notes call_number  keywords  language        date  \
# count                       10613       15983       0.0       0.0       16959
# unique                       6969       15936       NaN       NaN        6599
# top     Dieter Zander Collection.    1899-806       NaN       NaN  1915-01-01
# freq                          210           3       NaN       NaN         263
# mean                          NaN         NaN       NaN       NaN         NaN
# std                           NaN         NaN       NaN       NaN         NaN
# min                           NaN         NaN       NaN       NaN         NaN
# 25%                           NaN         NaN       NaN       NaN         NaN
# 50%                           NaN         NaN       NaN       NaN         NaN
# 75%                           NaN         NaN       NaN       NaN         NaN
# max                           NaN         NaN       NaN       NaN         NaN
#
#                location  location_type currency currency_symbol    status  \
# count             17545            0.0     6456            6456     17545
# unique             6283            NaN       42              34         2
# top     Waldorf Astoria            NaN  Dollars               $  complete
# freq                703            NaN     5549            5579     17371
# mean                NaN            NaN      NaN             NaN       NaN
# std                 NaN            NaN      NaN             NaN       NaN
# min                 NaN            NaN      NaN             NaN       NaN
# 25%                 NaN            NaN      NaN             NaN       NaN
# 50%                 NaN            NaN      NaN             NaN       NaN
# 75%                 NaN            NaN      NaN             NaN       NaN
# max                 NaN            NaN      NaN             NaN       NaN
#
#           page_count    dish_count
# count   17545.000000  17545.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean        3.484412     75.617213
# std         3.295643     98.435862
# min         1.000000      0.000000
# 25%         2.000000     20.000000
# 50%         2.000000     35.000000
# 75%         4.000000     93.000000
# max        74.000000   4053.000000

# %% [markdown]
# ## Missing Values - Section 2.1
#
# * `keywords`, `language`, and `location_type` are all at 100% missing
# * Other columns such as `name`, `currency` and others, are majorly missing information as well

# %%
missing_percentage = (df.isnull().sum() / len(df)) * 100
missing_percentage.name = 'Percentage of Missing Values'
missing_percentage
# Out:
# id                        0.000000
# name                     81.778284
# sponsor                   8.897122
# event                    53.525221
# venue                    53.724708
# place                    53.701909
# physical_description     15.856369
# occasion                 78.392704
# notes                    39.509832
# call_number               8.902821
# keywords                100.000000
# language                100.000000
# date                      3.339983
# location                  0.000000
# location_type           100.000000
# currency                 63.203192
# currency_symbol          63.203192
# status                    0.000000
# page_count                0.000000
# dish_count                0.000000
# Name: Percentage of Missing Values, dtype: float64

# %%
non_missing_percentage = 100 - missing_percentage
missing_data_percentage = pd.DataFrame({'Missing': missing_percentage, 'Non-Missing': non_missing_percentage})
missing_data_percentage.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Missing vs. Non-Missing Values (Percentage)')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.xticks(rotation=75)
plt.show()
